# %%
import platform

dict = {}

computer_details = platform.platform()

dict["Computer Details"] = computer_details

system_name = platform.system()

dict["System Details"] = system_name

processor_name = platform.processor()

dict["Processor Details"] = processor_name

architectural_details = platform.architecture()

dict["Architectural Details"] = architectural_details

for i, j in dict.items():
    print(i , "-" , j)
# Out:
# Computer Details - Windows-10-10.0.19041-SP0
# System Details - Windows
# Processor Details - Intel64 Family 6 Model 158 Stepping 10, GenuineIntel
# Architectural Details - ('64bit', 'WindowsPE')

# %%
#Chatbot I Made In The Class

import nltk
from nltk.chat.util import Chat, reflections

print(Chat)
reflections

set_pairs=[
    
    [ 
        r"my name is (.*)",
        ["Hello %1, how are you doing today?"]
    ],
    [
        r"hi|hey|hello",
        ["Hello","Hey there"]
    ],
    [
        r"What can i call you?",
        ["you can call me a chatbot or an assistant"]
    ],
    [
      r"i am fine, thank you",
        ["great to hear that, how can i help you?"]
    ],
    [
        r"how can i help you?",
        ["I am looking for courses to learn data science,can you suggest","i am looking for training platforms"]
    ],
    [
        r"i'm (.*) doing good",
        ["Thats great to hear","how can i help you"]
    ],
    [
        r"i am looking for online guides and courses to learn data science, can you suggest?",
        ["pluralsight is a great option to learn data science. you can check their website"]
    ],
    [
        r"thanks for the suggestion. do they have great authors and suggestions?",
        ["yes, they have world class best authors , that is their strength"]
    ],
    [
        r"(.*) thank you so much , that was helpful",
        ["i am happy to help","no problem, you are welcome"]
    ],
    [
        r"quit",
        ["bye, take care,see you soon :) ","it was nice talking to you, see you soon:)"]
    ],
]

def chatbot2():
    print("Hi, I am a Chatbot you built")
    
chatbot2()
chat = Chat(set_pairs , reflections)
print(chat)

chat.converse()

if __name__ == "__main__":
    chatbot2()
# Out:
# <class 'nltk.chat.util.Chat'>
# Hi, I am a Chatbot you built
# ...
# >quit
# it was nice talking to you, see you soon:)
# Hi, I am a Chatbot you built

# %%
#Chatbot I Made On my Own

import datetime
import nltk
from nltk.chat.util import Chat, reflections

reflections
  
set_pairs=[
    [ 
        r"my name is (.*)",
        ["Hello %1, how are you doing today?"]
    ],
    [
        r"hi|hey|hello|hola|bonjour|namaste",
        ["Hello","Hey there","How are you"]
    ],
    [
        r"What can i call you?",
        ["you can call me a chatbot"]
    ],
    [
        r"What is Machine Learning",
        ["Please find the definition on this page - https://en.wikipedia.org/wiki/Machine_learning"]
    ],
    [
      r"i am fine, thank you",
        ["great to hear that, how can i help you?"]
    ],
    [
        r"i'm (.*) doing good",
        ["Thats great to hear","how can i help you"]
    ],
    [
        r"quit|exit|see you soon",
        ["bye, take care,see you soon :) ","it was nice talking to you, see you soon:)","Will talk to you later"]
    ],
    [
        r"can you sing a song?",
        ["No, but you can listen to them here ; Enjoy :)  - https://www.youtube.com/ "]
    ],
    [
        r"what's up|how are you",
        ['Just doing my thing!', 'I am fine!', 'Nice!', 'I am nice and full of energy','i am okay ! How are you']
    ],
    [
        r"You are a chatbot of which branch?|You are a chatbot of which branch",
        ["I am an assistant of yours"]
    ],
]


def wish():
    hour = int(datetime.datetime.now().hour)
    if hour >= 0 and hour < 12:
        print("Good morning sir i am your Chatbot")
    elif hour >= 12 and hour < 16:
        print("Good afternoon sir i am your Chatbot")
    else:
        print("Good evening sir i am your Chatbot")
        

    

chat = Chat(set_pairs , reflections)
wish()
chat.converse()

# %%
# graphical window

import PySimpleGUI as sg

sg.Window(title="Hello World" , layout=[[]] , margins=(100,50)).read()
# Out:
# (None, [])

# %%
import PySimpleGUI as sg

layout = [[sg.Button("Hello World", size = (20,4))]]

sg.Window("Push My button" ,layout, size=(270,100)).read()
# Out:
# (None, {})

# %%
import PySimpleGUI as sg

layout = [[sg.Text("Primary Button: "),sg.Button("Hello World", size = (20,4))]]

sg.Window("Push My button" ,layout, size=(270,100)).read()
# Out:
# (None, {})

# %%
import PySimpleGUI as sg

layout = [
    [sg.Text("Whats Your Name")],
    [sg.Button("OK")] ]

window = sg.Window("Demo", layout)


while True:
    event, values = window.read()

    if event == "OK" or event == sg.WIN_CLOSED:
        break

window.close()

# %%
import PySimpleGUI as sg

layout = [
    [sg.Text("Whats Your Name")],
    [sg.Input()],
    [sg.Button("OK")] ]

window = sg.Window("PySimpleGUI", layout)
event, values = window.read()

print("Hello", values[0], "!Thanks for trying PySimpleGUI")
window.close()
# Out:
# Hello Parth !Thanks for trying this

# %%
import PySimpleGUI as sg

layout = [
    [sg.Text("Whats Your First Name")],
    [sg.Input()],
    [sg.Text("Whats Your Last Name")],
    [sg.Input()],
    [sg.Button("OK")] ]

window = sg.Window("PySimpleGUI", layout)
event, values = window.read()

print("Hello", values[0],values[1], "!Thanks for trying PySimpleGUI")
window.close()
# Out:
# Hello parth vii !Thanks for trying PySimpleGUI

# %%
import PySimpleGUI as sg

layout = [
    [sg.Text("Whats Your First Name")],
    [sg.Input(key='-INPUT-')],
    [sg.Text(size=(40,1),key = ('-OUTPUT-'))],
    [sg.Button("OK"),sg.Button("Quit")] ]

window = sg.Window("PySimpleGUI", layout)

while True:
    event, values = window.read()
    if event == sg.WINDOW_CLOSED or event == "Quit":
        break
    window['-OUTPUT-'].update('Hello '+values['-INPUT-']+"! Thanks for trying PySimpleGUI")

window.close()

# %%
import PySimpleGUI as sg

sg.theme('Black')
layout = [
    [sg.Text("Whats Your First Name")],
    [sg.Input()],
    [sg.Text("Whats Your Last Name")],
    [sg.Input()],
    [sg.Button("OK"),sg.Button("Quit")] ] 

window = sg.Window("PySimpleGUI", layout)
event, values = window.read()

print("Hello", values[0],values[1], "!Thanks for trying PySimpleGUI")
window.close()
# Out:
# Hello Parth Khatkar !Thanks for trying PySimpleGUI

# %%
# !pip install PySimpleGUI
import PySimpleGUI as sg

sg.theme('Black')
layout = [
    [sg.Text("Enter Your Passcode")],
    [sg.Input(size=(10,1), justification='right', key = 'input')],
    [sg.Button("1"),sg.Button("2"),sg.Button("3")],
    [sg.Button("4"),sg.Button("5"),sg.Button("6")],
    [sg.Button("7"),sg.Button("8"),sg.Button("9")],
    [sg.Button("Submit"),sg.Button("0"),sg.Button("Clear")],
    [sg.Text(size =(15,1), font =("Helvetica",18), text_color = ("Red"), key = "out")]
]

window=sg.Window("Keypad", layout, default_button_element_size = (5,2), auto_size_buttons = False)
keys_entered=''
while True:
    event, values = window.read()
    if event == sg.WIN_CLOSED or event == "Quit":
        break
    if event == 'Clear':  # clear keys if clear button
        keys_entered = ''
    elif event in '1234567890':
        keys_entered = values['input']  # get what's been entered so far
        keys_entered += event  # add the new digit
    elif event == 'Submit':
        keys_entered = values['input']
        window['out'].update(keys_entered)  # output the final string

    window['input'].update(keys_entered)
# Out:
# ...
#    ---------------------------------------- 1.0/1.0 MB 5.8 MB/s eta 0:00:00
# ...

# %%
import tkinter as tk

m = tk.Tk()
m.title("Counting Seconds")
button = tk.Button(m, text="stop" , width =25, command = m.destroy)
button.grid()
m.mainloop()

# %%
from tkinter import *
m = Tk()
var1 = IntVar()
Checkbutton(m, text="Male", variable=var1).grid(row=0, sticky = W)
var2 = IntVar()
Checkbutton(m, text="Female", variable=var2).grid(row=1, sticky = W)
var3 = IntVar()
Checkbutton(m, text="Other", variable=var3).grid(row=2, sticky = W)
var4 = IntVar()
Checkbutton(m, text="Send Me an E-Mail", variable=var4).grid(row=3, sticky = W)
mainloop()

# %%
from tkinter import *
m = Tk()
Label(m, text = "First Name").grid(row=0)
Label(m, text = "Last Name").grid(row=1)
Label(m, text = "Class").grid(row=0,column=2)
Label(m, text = "Section").grid(row=1,column=2)
e1 = Entry().grid(row=0,column=1)
e2 = Entry().grid(row=1,column=1)
e3 = Entry().grid(row=0,column=3)
e4 = Entry().grid(row=1,column=3)
mainloop()

# %%
from tkinter import *
m = Tk()
frame= Frame(m)
frame.pack()
Bottomframe = Frame(m)
Bottomframe.pack(side = BOTTOM)
redbutton= Button(frame, text="red", fg="red")
redbutton.pack(side = LEFT)
greenbutton= Button(frame, text="green", fg="green")
greenbutton.pack(side = LEFT)
bluebutton= Button(frame, text="blue", fg="blue")
bluebutton.pack(side = LEFT)
blackbutton= Button(Bottomframe, text="black", fg="black")
blackbutton.pack(side = BOTTOM)
m.mainloop()

# %%
from tkinter import *
m = Tk()
w = Label(m, text="GeeksForGeeks.org!")
w.pack()
m.mainloop()

# %%
from tkinter import *
m = Tk()

L = Listbox(m)
L.insert(1, "Python")
L.insert(2, "Java")
L.insert(3, "C++")
L.insert(4, "Any Other")
L.pack()
m.mainLoop()

# %%
from tkinter import *
m = Tk()

mb = Menubutton (m, text="File")
mb.menu = Menu(mb, tearoff = 0)

cVar = IntVar()
aVar = IntVar()
dVar = IntVar()
gVar = IntVar()

mb.menu.add_checkbutton(label='Contact', variable=cVar)
mb.menu.add_checkbutton(label='About', variable=aVar)
mb.menu.add_checkbutton(label='Open', variable=dVar)
mb.menu.add_checkbutton(label='Exit', variable=gVar)

mb.pack()
m.mainloop()

# %%
from tkinter import *
t = Tk()

menu = Menu(t)
t.config(menu=menu)

filemenu = Menu(menu)

menu.add_cascade(label = "File", menu=filemenu)
filemenu.add_command(label="New")
filemenu.add_command(label="Open...")
filemenu.add_separator()
filemenu.add_command(label="Exit",command=t.quit)

helpmenu = Menu(menu)

menu.add_cascade(label = "Help", menu=helpmenu)
helpmenu.add_command(label="Terms And Conditions")
helpmenu.add_command(label="Check For Updates")
helpmenu.add_command(label="About")

editmenu = Menu(menu)

menu.add_cascade(label = "Edit", menu=editmenu)
editmenu.add_command(label="Themes")
editmenu.add_command(label="Copy")
editmenu.add_command(label="Paste")

mainloop()

# %%
from tkinter import *
t = Tk()

message = "Hi, I am Parth Khatkar"
messageVar = Message(t, text= message)
messageVar.config(bg="black", fg="white")
messageVar.pack()
t.mainloop()

# %%
from tkinter import *
m = Tk()
var1 = IntVar()
Radiobutton(m, text="A", variable=var1, value = 1).pack(anchor = W)

Radiobutton(m, text="B", variable=var1, value=2).pack(anchor = W)

Radiobutton(m, text="C", variable=var1, value=3).pack(anchor = W)

Radiobutton(m, text="D", variable=var1, value=4).pack(anchor = W)
mainloop()

# %%
from tkinter import *
master = Tk()
w = Scale(master, from_=0, to=42)
w.pack()
w = Scale(master, from_=0, to=200, orient=HORIZONTAL)
w.pack()
mainloop()

# %%
from tkinter import *
m = Tk()
scrollbar = Scrollbar(m)
scrollbar.pack(side = RIGHT, fill = Y)
mylist = Listbox(m , yscrollcommand = scrollbar.set)
for line in range(100):
    mylist.insert(END, "This is a line number"+ str(line))
mylist.pack(side = LEFT, fill = BOTH)
scrollbar.config(command=mylist.yview)
mainloop()

# %%
from tkinter import *
m = Tk()
t = Text(m, height = 2, width = 30)
t.pack()
t.insert(END,"GeeksForGeeks\nThe Best Website Ever Created\n" )
mainloop()

# %%
from tkinter import *
root=Tk()
root.title('GFG')
top=Toplevel()
top.title('Python')
top.mainloop()

# %%
from tkinter import *
master = Tk()
w = Spinbox(master, from_=0, to=120)
w.pack()
mainloop()

# %%
from tkinter import *
m1 = PanedWindow()
m1.pack(fill = BOTH, expand=1)
left = Entry(m1, bd=5)
m1.add(left)
m2 = PanedWindow(m1, orient = VERTICAL)
m1.add(m2)
top = Scale(m2, orient = HORIZONTAL)
m2.add(top)
mainloop()

# %%
# import everything from tkinter module 
from tkinter import *
  
# globally declare the expression variable 
expression = "" 
  
  
# Function to update expression
# in the text entry box 
def press(num): 
    # point out the global expression variable 
    global expression 
  
    # concatenation of string 
    expression = expression + str(num) 
  
    # update the expression by using set method 
    equation.set(expression) 
  
  
# Function to evaluate the final expression 
def equalpress(): 
    # Try and except statement is used 
    # for handling the errors like zero 
    # division error etc. 
  
    # Put that code inside the try block 
    # which may generate the error 
    try: 
  
        global expression 
  
        # eval function evaluate the expression 
        # and str function convert the result 
        # into string 
        total = str(eval(expression)) 
  
        equation.set(total) 
  
        # initialze the expression variable 
        # by empty string 
        expression = "" 
  
    # if error is generate then handle 
    # by the except block 
    except: 
  
        equation.set(" error ") 
        expression = "" 
  
  
# Function to clear the contents 
# of text entry box 
def clear(): 
    global expression 
    expression = "" 
    equation.set("") 
  
  
# Driver code 
if __name__ == "__main__": 
    # create a GUI window 
    gui = Tk() 
  
    # set the background colour of GUI window 
    gui.configure(background="black") 
  
    # set the title of GUI window 
    gui.title("Simple Calculator") 
  
    # set the configuration of GUI window 
    gui.geometry("270x150") 
  
    # StringVar() is the variable class 
    # we create an instance of this class 
    equation = StringVar() 
  
    # create the text entry box for 
    # showing the expression . 
    expression_field = Entry(gui, textvariable=equation) 
  
    # grid method is used for placing 
    # the widgets at respective positions 
    # in table like structure . 
    expression_field.grid(columnspan=4, ipadx=70) 
  
    equation.set('enter your expression') 
   
    button1 = Button(gui, text=' 1 ', fg='black', bg = "light blue", 
                     command=lambda: press(1), height=1, width=7) 
    button1.grid(row=2, column=0) 
  
    button2 = Button(gui, text=' 2 ', fg='black', bg = "light blue", 
                     command=lambda: press(2), height=1, width=7) 
    button2.grid(row=2, column=1) 
  
    button3 = Button(gui, text=' 3 ', fg='black', bg = "light blue", 
                     command=lambda: press(3), height=1, width=7) 
    button3.grid(row=2, column=2) 
  
    button4 = Button(gui, text=' 4 ', fg='black', bg = "light blue", 
                     command=lambda: press(4), height=1, width=7) 
    button4.grid(row=3, column=0) 
  
    button5 = Button(gui, text=' 5 ', fg='black', bg = "light blue", 
                     command=lambda: press(5), height=1, width=7) 
    button5.grid(row=3, column=1) 
  
    button6 = Button(gui, text=' 6 ', fg='black', bg = "light blue", 
                     command=lambda: press(6), height=1, width=7) 
    button6.grid(row=3, column=2) 
  
    button7 = Button(gui, text=' 7 ', fg='black', bg = "light blue", 
                     command=lambda: press(7), height=1, width=7) 
    button7.grid(row=4, column=0) 
  
    button8 = Button(gui, text=' 8 ', fg='black', bg = "light blue", 
                     command=lambda: press(8), height=1, width=7) 
    button8.grid(row=4, column=1) 
  
    button9 = Button(gui, text=' 9 ', fg='black', bg = "light blue", 
                     command=lambda: press(9), height=1, width=7) 
    button9.grid(row=4, column=2) 
  
    button0 = Button(gui, text=' 0 ', fg='black', bg = "light blue", 
                     command=lambda: press(0), height=1, width=7) 
    button0.grid(row=5, column=0) 
  
    plus = Button(gui, text=' + ', fg='black', bg = "light blue", 
                  command=lambda: press("+"), height=1, width=7) 
    plus.grid(row=2, column=3) 
  
    minus = Button(gui, text=' - ', fg='black', bg = "light blue", 
                   command=lambda: press("-"), height=1, width=7) 
    minus.grid(row=3, column=3) 
  
    multiply = Button(gui, text=' * ', fg='black', bg = "light blue", 
                      command=lambda: press("*"), height=1, width=7) 
    multiply.grid(row=4, column=3) 
  
    divide = Button(gui, text=' / ', fg='black', bg = "light blue", 
                    command=lambda: press("/"), height=1, width=7) 
    divide.grid(row=5, column=3) 
  
    equal = Button(gui, text=' = ', fg='black', bg = "light blue", 
                   command=equalpress, height=1, width=7) 
    equal.grid(row=5, column=2) 
  
    clear = Button(gui, text='Clear', fg='black', bg = "light blue", 
                   command=clear, height=1, width=7) 
    clear.grid(row=5, column='1') 
  
    Decimal= Button(gui, text='.', fg='black', bg = "light blue", 
                    command=lambda: press('.'), height=1, width=7) 
    Decimal.grid(row=6, column=0) 
    # start the GUI 
    gui.mainloop()

# %%
# import all functions / classes from the tkinter   
from tkinter import * 
from textblob import TextBlob 
  
# Function to clear both the text entry boxes 
def clearAll() : 
      
    # whole content of text entry area  is deleted  
    word1_field.delete(0, END) 
    word2_field.delete(0, END) 
  
# Function to get a corrected word 
def correction() : 
  
    # get a content from entry box 
    input_word = word1_field.get() 
  
    # create a TextBlob object 
    blob_obj = TextBlob(input_word) 
  
    # get a corrected word 
    corrected_word = str(blob_obj.correct()) 
  
    # insert method inserting the   
    # value in the text entry box. 
    word2_field.insert(10, corrected_word) 
  
  
# Driver code  
if __name__ == "__main__" :  -
  
    # Create a GUI window  
    root = Tk() 
  
    # Set the background colour of GUI window   
    root.configure(background = 'light green')   
      
    # Set the configuration of GUI window (WidthxHeight)  
    root.geometry("400x150")   
  
    # set the name of tkinter GUI window   
    root.title("Spell Corrector") 
      
    # Create Welcome to Spell Corrector Application: label   
    headlabel = Label(root, text = 'Welcome to Spell Corrector Application',   
                      fg = 'black', bg = "light blue")   
    
    # Create a "Input Word": label   
    label1 = Label(root, text = "Input Word",  
                 fg = 'black', bg = 'dark green')  
        
    # Create a "Corrected Word": label   
    label2 = Label(root, text = "Corrected Word",   
                   fg = 'black', bg = 'dark green')   
      
    
    # grid method is used for placing   
    # the widgets at respective positions   
    # in table like structure . 
    # padx keyword argument used to set paading along x-axis . 
    headlabel.grid(row = 0, column = 1)   
    label1.grid(row = 1, column = 0)   
    label2.grid(row = 3, column = 0, padx = 10)  
  
        
    # Create a text entry box   
    # for filling or typing the information.   
    word1_field = Entry()  
    word2_field = Entry() 
         
    # padx keyword argument used to set paading along x-axis . 
    # pady keyword argument used to set paading along y-axis .   
    word1_field.grid(row = 1, column = 1, padx = 10, pady = 10)   
    word2_field.grid(row = 3, column = 1, padx = 10, pady = 10)  
  
        
    # Create a Correction Button and attached   
    # with correction function   
    button1 = Button(root, text = "Correction", bg = "light blue", fg = "black",  command = correction)  
        
    button1.grid(row = 2, column = 1)  
    
    # Create a Clear Button and attached   
    # with clearAll function   
    button2 = Button(root, text = "Clear", bg = "light blue",   fg = "black", command = clearAll) 
      
    button2.grid(row = 4, column = 1)  
      
    # Start the GUI   
    root.mainloop()

# %%
#Dollar to Rupee

from tkinter import *

window = Tk()
window.title("Dollar to Rupee")
window.config(padx = 20,pady = 20)

def d_2_r():
    dollar = int(dollar_input.get())
    result = dollar * 82.79
    rupee_result.config(text=result)

dollar_input = Entry()
dollar = Label(text="Dollar")
is_eql_label = Label(text="is equal to")
rupee = Label(text="Rupee")
rupee_result = Label(text="0")
cal = Button(text="Calculate", command = d_2_r)

dollar.grid(row=0,column=0)
dollar_input.grid(row=0,column=1)
is_eql_label.grid(row=1,column=0)
rupee_result.grid(row=1,column=1)
rupee.grid(row=1,column=2)
cal.grid(row=2,column=1)





window.mainloop()

# %%
#Tic Tac Toe

import tkinter
from tkinter import *
from tkinter import messagebox

root = Tk()
root.title("Tic Tac Toe")

clicked = True
count = 0
def b_click(b):
    global clicked,count
    if b["text"] == " " and clicked == True:
        b["text"] = "X"
        clicked = False
        count += 1
        checkifwon()
    elif b["text"] == " " and clicked == False:
        b["text"] = "O"
        clicked = True
        count += 1
        checkifwon()
    else:
        messagebox.showerror("Tic Tac Toe","this box has already been taken!!")


def checkifwon():
    global winner
    winner = False
    if b1["text"] == "X" and b2["text"] == "X" and b3["text"] == "X":
        b1.config(bg="green")
        b2.config(bg="green")
        b3.config(bg="green")
        winner = True
        messagebox.showinfo("Tic Tac Toe", "Hurrayyy!!! X wins")
        disable_a_b()
    elif b4["text"] == "X" and b5["text"] == "X" and b6["text"] == "X":
        b4.config(bg="green")
        b5.config(bg="green")
        b6.config(bg="green")
        winner = True
        messagebox.showinfo("Tic Tac Toe", "Hurrayyy!!! X wins")
        disable_a_b()
    elif b7["text"] == "X" and b8["text"] == "X" and b9["text"] == "X":
        b7.config(bg="green")
        b8.config(bg="green")
        b9.config(bg="green")
        winner = True
        messagebox.showinfo("Tic Tac Toe", "Hurrayyy!!! X wins")
        disable_a_b()


    elif b1["text"] == "X" and b4["text"] == "X" and b7["text"] == "X":
        b1.config(bg="green")
        b4.config(bg="green")
        b7.config(bg="green")
        winner = True
        messagebox.showinfo("Tic Tac Toe", "Hurrayyy!!! X wins")
        disable_a_b()
    elif b2["text"] == "X" and b5["text"] == "X" and b8["text"] == "X":
        b2.config(bg="green")
        b5.config(bg="green")
        b8.config(bg="green")
        winner = True
        messagebox.showinfo("Tic Tac Toe", "Hurrayyy!!! X wins")
        disable_a_b()
    elif b3["text"] == "X" and b6["text"] == "X" and b9["text"] == "X":
        b3.config(bg="green")
        b6.config(bg="green")
        b9.config(bg="green")
        winner = True
        messagebox.showinfo("Tic Tac Toe", "Hurrayyy!!! X wins")
        disable_a_b()


    elif b1["text"] == "X" and b5["text"] == "X" and b9["text"] == "X":
        b1.config(bg="green")
        b5.config(bg="green")
        b9.config(bg="green")
        winner = True
        messagebox.showinfo("Tic Tac Toe", "Hurrayyy!!! X wins")
        disable_a_b()
    elif b3["text"] == "X" and b5["text"] == "X" and b7["text"] == "X":
        b3.config(bg="green")
        b5.config(bg="green")
        b7.config(bg="green")
        winner = True
        messagebox.showinfo("Tic Tac Toe", "Hurrayyy!!! X wins")
        disable_a_b()

    elif b1["text"] == "O" and b2["text"] == "O" and b3["text"] == "O":
        b1.config(bg="green")
        b2.config(bg="green")
        b3.config(bg="green")
        winner = True
        messagebox.showinfo("Tic Tac Toe", "Hurrayyy!!! O wins")
        disable_a_b()
    elif b4["text"] == "O" and b5["text"] == "O" and b6["text"] == "O":
        b4.config(bg="green")
        b5.config(bg="green")
        b6.config(bg="green")
        winner = True
        messagebox.showinfo("Tic Tac Toe", "Hurrayyy!!! O wins")
        disable_a_b()
    elif b7["text"] == "O" and b8["text"] == "O" and b9["text"] == "O":
        b7.config(bg="green")
        b8.config(bg="green")
        b9.config(bg="green")
        winner = True
        messagebox.showinfo("Tic Tac Toe", "Hurrayyy!!! O wins")
        disable_a_b()


    elif b1["text"] == "O" and b4["text"] == "O" and b7["text"] == "O":
        b1.config(bg="green")
        b4.config(bg="green")
        b7.config(bg="green")
        winner = True
        messagebox.showinfo("Tic Tac Toe", "Hurrayyy!!! O wins")
        disable_a_b()
    elif b2["text"] == "O" and b5["text"] == "O" and b8["text"] == "O":
        b2.config(bg="green")
        b5.config(bg="green")
        b8.config(bg="green")
        winner = True
        messagebox.showinfo("Tic Tac Toe", "Hurrayyy!!! O wins")
        disable_a_b()
    elif b3["text"] == "O" and b6["text"] == "O" and b9["text"] == "O":
        b3.config(bg="green")
        b6.config(bg="green")
        b9.config(bg="green")
        winner = True
        messagebox.showinfo("Tic Tac Toe", "Hurrayyy!!! O wins")
        disable_a_b()


    elif b1["text"] == "O" and b5["text"] == "O" and b9["text"] == "O":
        b7.config(bg="green")
        b8.config(bg="green")
        b9.config(bg="green")
        winner = True
        messagebox.showinfo("Tic Tac Toe", "Hurrayyy!!! O wins")
        disable_a_b()
    elif b3["text"] == "O" and b5["text"] == "O" and b7["text"] == "O":
        b7.config(bg="green")
        b8.config(bg="green")
        b9.config(bg="green")
        winner = True
        messagebox.showinfo("Tic Tac Toe", "Hurrayyy!!! O wins")
        disable_a_b()

    if count == 9 and winner == False:
        messagebox.showinfo("Tic Tac Toe", "It's a tie")
        disable_a_b()


def disable_a_b():
    b1.configure(state = DISABLED)
    b2.configure(state = DISABLED)
    b3.configure(state = DISABLED)
    b4.configure(state = DISABLED)
    b5.configure(state = DISABLED)
    b6.configure(state = DISABLED)
    b7.configure(state = DISABLED)
    b8.configure(state = DISABLED)
    b9.configure(state = DISABLED)
    pass

def reset():

    global b1,b2,b3,b4,b5,b6,b7,b8,b9
    global clicked,count

    clicked = True
    count = 0

    b1= Button(root,text=" ", font=("halvetica,20"), height=3,width=6,bg="grey",command=lambda:b_click(b1))
    b2= Button(root,text=" ", font=("halvetica,20"), height=3,width=6,bg="grey",command=lambda:b_click(b2))
    b3= Button(root,text=" ", font=("halvetica,20"), height=3,width=6,bg="grey",command=lambda:b_click(b3))
    b4= Button(root,text=" ", font=("halvetica,20"), height=3,width=6,bg="grey",command=lambda:b_click(b4))
    b5= Button(root,text=" ", font=("halvetica,20"), height=3,width=6,bg="grey",command=lambda:b_click(b5))
    b6= Button(root,text=" ", font=("halvetica,20"), height=3,width=6,bg="grey",command=lambda:b_click(b6))
    b7= Button(root,text=" ", font=("halvetica,20"), height=3,width=6,bg="grey",command=lambda:b_click(b7))
    b8= Button(root,text=" ", font=("halvetica,20"), height=3,width=6,bg="grey",command=lambda:b_click(b8))
    b9= Button(root,text=" ", font=("halvetica,20"), height=3,width=6,bg="grey",command=lambda:b_click(b9))

    b1.grid(row=0,column=0)
    b2.grid(row=0,column=1)
    b3.grid(row=0,column=2)
    b4.grid(row=1,column=0)
    b5.grid(row=1,column=1)
    b6.grid(row=1,column=2)
    b7.grid(row=2,column=0)
    b8.grid(row=2,column=1)
    b9.grid(row=2,column=2)

my_menu = Menu(root)
root.config(menu = my_menu)
opt_menu = Menu(my_menu, tearoff = False )
my_menu.add_cascade(label="Option", menu = opt_menu)
opt_menu.add_command(label = "Reset Game", command = reset)

reset()
root.mainloop()
